# %% [markdown]
# The link for Git : https://github.com/cmphat/AI-Agent-Lab-UTE.git

# %% [markdown]
# The link for (images) in Google Drive: https://drive.google.com/drive/folders/1HNzC16Jf-uLdKWRX3Shfa1mEqKJ9C5c8?usp=sharing
